# %% [markdown]
# # Finale

# %%
import requests
from bs4 import BeautifulSoup
import csv
import chardet
import os
import time

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}


def get_club_names(url):
    """Récupère la liste des clubs d’un championnat à partir de Transfermarkt."""
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"❌ Erreur {response.status_code} pour {url}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    table = soup.find("table", class_="items")
    if not table:
        print(f"⚠️ Tableau introuvable pour {url}")
        return []

    clubs = []
    rows = table.find("tbody").find_all("tr")
    for row in rows:
        cols = row.find_all("td")
        if len(cols) >= 3:
            team = cols[1].get_text(strip=True)
            clubs.append(team)
    return clubs


def save_to_csv(clubs, filename="clubs.csv"):
    """Sauvegarde les clubs dans un fichier CSV."""
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Championnat", "Club"])
        for championnat, club in clubs:
            writer.writerow([championnat, club])
    print(f"\n💾 {len(clubs)} clubs sauvegardés dans {os.path.abspath(filename)}")


def lire_championnats_csv(fichier_csv):
    """Lit la liste des championnats depuis le CSV d’entrée."""
    with open(fichier_csv, "rb") as f:
        encodage = chardet.detect(f.read())["encoding"]
    with open(fichier_csv, "r", encoding=encodage) as f:
        reader = csv.reader(f)
        next(reader)  # ignorer l’en-tête
        for row in reader:
            if len(row) >= 3 and row[2].startswith("https"):
                yield row[0].strip(), row[2].strip()


def main():
    all_clubs = []
    fichier_csv = "../championnat/championnat_finale.csv"
    sortie = "clubs/clubs.csv"

    print("🚀 Début du scraping des championnats...\n")

    for championnat, lien in lire_championnats_csv(fichier_csv):
        print(f"🔄 Traitement en cours : {championnat}")
        clubs = get_club_names(lien)
        if clubs:
            for club in clubs:
                all_clubs.append((championnat, club))
            print(f"✅ {len(clubs)} clubs trouvés pour {championnat}\n")
        else:
            print(f"⚠️ Aucun club trouvé pour {championnat}\n")
        time.sleep(1.5)  # petite pause pour éviter le blocage par Transfermarkt

    if all_clubs:
        save_to_csv(all_clubs, sortie)
    else:
        print("❌ Aucun club récupéré.")

    print("\n🏁 Fin du programme.")


if __name__ == "__main__":
    main()
# Out:
# 🚀 Début du scraping des championnats...
#
# 🔄 Traitement en cours : 1
# ✅ 20 clubs trouvés pour 1
#
# 🔄 Traitement en cours : 2
# ✅ 20 clubs trouvés pour 2
#
# 🔄 Traitement en cours : 3
# ✅ 20 clubs trouvés pour 3
#
# 🔄 Traitement en cours : 4
# ✅ 18 clubs trouvés pour 4
#
# 🔄 Traitement en cours : 5
# ✅ 18 clubs trouvés pour 5
#
# 🔄 Traitement en cours : 7
# ✅ 24 clubs trouvés pour 7
#
# 🔄 Traitement en cours : 6
# ✅ 20 clubs trouvés pour 6
#
# 🔄 Traitement en cours : 8
# ✅ 18 clubs trouvés pour 8
#
# 🔄 Traitement en cours : 11
# ✅ 30 clubs trouvés pour 11
#
# 🔄 Traitement en cours : 10
# ✅ 18 clubs trouvés pour 10
#
# 🔄 Traitement en cours : 9
# ✅ 18 clubs trouvés pour 9
#
# 🔄 Traitement en cours : 12
# ✅ 18 clubs trouvés pour 12
#
# 🔄 Traitement en cours : 13
# ✅ 16 clubs trouvés pour 13
#
# 🔄 Traitement en cours : 14
# ✅ 30 clubs trouvés pour 14
#
# 🔄 Traitement en cours : 15
# ✅ 30 clubs trouvés pour 15
#
# 🔄 Traitement en cours : 16
# ✅ 16 clubs trouvés pour 16
#
# 🔄 Traitement en cours : 17
# ✅ 18 clubs trouvés pour 17
#
# 🔄 Traitement en cours : 18
# ✅ 18 clubs trouvés pour 18
#
# 🔄 Traitement en cours : 19
# ✅ 14 clubs trouvés pour 19
#
# 🔄 Traitement en cours : 20
# ✅ 20 clubs trouvés pour 20
#
# 🔄 Traitement en cours : 21
# ✅ 18 clubs trouvés pour 21
#
# 🔄 Traitement en cours : 22
# ✅ 22 clubs trouvés pour 22
#
# 🔄 Traitement en cours : 23
# ✅ 12 clubs trouvés pour 23
#
# 🔄 Traitement en cours : 24
# ✅ 12 clubs trouvés pour 24
#
# 🔄 Traitement en cours : 25
# ✅ 16 clubs trouvés pour 25
#
# 🔄 Traitement en cours : 26
# ✅ 14 clubs trouvés pour 26
#
# 🔄 Traitement en cours : 27
# ✅ 16 clubs trouvés pour 27
#
# 🔄 Traitement en cours : 28
# ✅ 12 clubs trouvés pour 28
#
# 🔄 Traitement en cours : 29
# ✅ 18 clubs trouvés pour 29
#
# 🔄 Traitement en cours : 30
# ✅ 12 clubs trouvés pour 30
#
# 🔄 Traitement en cours : 31
# ✅ 12 clubs trouvés pour 31
#
# 🔄 Traitement en cours : 32
# ✅ 18 clubs trouvés pour 32
#
# 🔄 Traitement en cours : 33
# ✅ 16 clubs trouvés pour 33
#
# 🔄 Traitement en cours : 34
# ✅ 20 clubs trouvés pour 34
#
# 🔄 Traitement en cours : 35
# ✅ 24 clubs trouvés pour 35
#
# 🔄 Traitement en cours : 36
# ✅ 16 clubs trouvés pour 36
#
# 🔄 Traitement en cours : 37
# ✅ 16 clubs trouvés pour 37
#
# 🔄 Traitement en cours : 38
# ✅ 16 clubs trouvés pour 38
#
# 🔄 Traitement en cours : 39
# ✅ 20 clubs trouvés pour 39
#
# 🔄 Traitement en cours : 40
# ✅ 10 clubs trouvés pour 40
#
# 🔄 Traitement en cours : 41
# ✅ 20 clubs trouvés pour 41
#
# 🔄 Traitement en cours : 42
# ✅ 20 clubs trouvés pour 42
#
# 🔄 Traitement en cours : 43
# ✅ 16 clubs trouvés pour 43
#
# 🔄 Traitement en cours : 44
# ✅ 16 clubs trouvés pour 44
#
# 🔄 Traitement en cours : 45
# ✅ 16 clubs trouvés pour 45
#
# 🔄 Traitement en cours : 46
# ✅ 16 clubs trouvés pour 46
#
# 🔄 Traitement en cours : 47
# ✅ 16 clubs trouvés pour 47
#
# 🔄 Traitement en cours : 48
# ✅ 16 clubs trouvés pour 48
#
# 🔄 Traitement en cours : 49
# ✅ 21 clubs trouvés pour 49
#
# 🔄 Traitement en cours : 50
# ✅ 2 clubs trouvés pour 50
#
# 🔄 Traitement en cours : 51
# ✅ 20 clubs trouvés pour 51
#
# 🔄 Traitement en cours : 52
# ✅ 14 clubs trouvés pour 52
#
# 🔄 Traitement en cours : 53
# ✅ 18 clubs trouvés pour 53
#
# 🔄 Traitement en cours : 54
# ✅ 12 clubs trouvés pour 54
#
# 🔄 Traitement en cours : 55
# ✅ 16 clubs trouvés pour 55
#
# 🔄 Traitement en cours : 56
# ✅ 5 clubs trouvés pour 56
#
# 🔄 Traitement en cours : 57
# ✅ 14 clubs trouvés pour 57
#
# 🔄 Traitement en cours : 58
# ✅ 20 clubs trouvés pour 58
#
# 🔄 Traitement en cours : 59
# ✅ 20 clubs trouvés pour 59
#
# 🔄 Traitement en cours : 60
# ✅ 20 clubs trouvés pour 60
#
# 🔄 Traitement en cours : 61
# ✅ 16 clubs trouvés pour 61
#
# 🔄 Traitement en cours : 62
# ✅ 18 clubs trouvés pour 62
#
# 🔄 Traitement en cours : 63
# ✅ 19 clubs trouvés pour 63
#
# 🔄 Traitement en cours : 64
# ✅ 18 clubs trouvés pour 64
#
# 🔄 Traitement en cours : 65
# ✅ 17 clubs trouvés pour 65
#
# 🔄 Traitement en cours : 66
# ✅ 16 clubs trouvés pour 66
#
# 🔄 Traitement en cours : 67
# ✅ 12 clubs trouvés pour 67
#
# 🔄 Traitement en cours : 68
# ✅ 12 clubs trouvés pour 68
#
# 🔄 Traitement en cours : 69
# ✅ 12 clubs trouvés pour 69
#
# 🔄 Traitement en cours : 70
# ✅ 16 clubs trouvés pour 70
#
# 🔄 Traitement en cours : 71
# ✅ 20 clubs trouvés pour 71
#
# 🔄 Traitement en cours : 72
# ✅ 12 clubs trouvés pour 72
#
# 🔄 Traitement en cours : 73
# ✅ 36 clubs trouvés pour 73
#
# 🔄 Traitement en cours : 74
# ✅ 20 clubs trouvés pour 74
#
# 🔄 Traitement en cours : 75
# ✅ 12 clubs trouvés pour 75
#
# 🔄 Traitement en cours : 76
# ✅ 20 clubs trouvés pour 76
#
# 🔄 Traitement en cours : 77
# ✅ 16 clubs trouvés pour 77
#
# 🔄 Traitement en cours : 78
# ✅ 20 clubs trouvés pour 78
#
# 🔄 Traitement en cours : 79
# ✅ 24 clubs trouvés pour 79
#
# 🔄 Traitement en cours : 80
# ✅ 5 clubs trouvés pour 80
#
# 🔄 Traitement en cours : 81
# ✅ 24 clubs trouvés pour 81
#
# 🔄 Traitement en cours : 82
# ✅ 20 clubs trouvés pour 82
#
# 🔄 Traitement en cours : 83
# ✅ 20 clubs trouvés pour 83
#
# 🔄 Traitement en cours : 84
# ✅ 15 clubs trouvés pour 84
#
# 🔄 Traitement en cours : 85
# ✅ 15 clubs trouvés pour 85
#
# 🔄 Traitement en cours : 86
# ✅ 12 clubs trouvés pour 86
#
# 🔄 Traitement en cours : 87
# ✅ 14 clubs trouvés pour 87
#
# 🔄 Traitement en cours : 88
# ✅ 16 clubs trouvés pour 88
#
# 🔄 Traitement en cours : 89
# ✅ 16 clubs trouvés pour 89
#
# 🔄 Traitement en cours : 90
# ✅ 5 clubs trouvés pour 90
#
# 🔄 Traitement en cours : 91
# ✅ 18 clubs trouvés pour 91
#
# 🔄 Traitement en cours : 92
# ✅ 14 clubs trouvés pour 92
#
# 🔄 Traitement en cours : 93
# ✅ 18 clubs trouvés pour 93
#
# 🔄 Traitement en cours : 94
# ✅ 16 clubs trouvés pour 94
#
# 🔄 Traitement en cours : 95
# ✅ 16 clubs trouvés pour 95
#
# 🔄 Traitement en cours : 96
# ✅ 16 clubs trouvés pour 96
#
# 🔄 Traitement en cours : 97
# ✅ 18 clubs trouvés pour 97
#
# 🔄 Traitement en cours : 98
# ✅ 20 clubs trouvés pour 98
#
# 🔄 Traitement en cours : 99
# ✅ 16 clubs trouvés pour 99
#
# 🔄 Traitement en cours : 100
# ✅ 14 clubs trouvés pour 100
#
# 🔄 Traitement en cours : 101
# ✅ 14 clubs trouvés pour 101
#
# 🔄 Traitement en cours : 102
# ✅ 32 clubs trouvés pour 102
#
# 🔄 Traitement en cours : 103
# ✅ 16 clubs trouvés pour 103
#
# 🔄 Traitement en cours : 104
# ✅ 12 clubs trouvés pour 104
#
# 🔄 Traitement en cours : 105
# ✅ 20 clubs trouvés pour 105
#
# 🔄 Traitement en cours : 106
# ✅ 16 clubs trouvés pour 106
#
# 🔄 Traitement en cours : 107
# ✅ 10 clubs trouvés pour 107
#
# 🔄 Traitement en cours : 108
# ✅ 17 clubs trouvés pour 108
#
# 🔄 Traitement en cours : 109
# ✅ 16 clubs trouvés pour 109
#
# 🔄 Traitement en cours : 110
# ✅ 16 clubs trouvés pour 110
#
# 🔄 Traitement en cours : 111
# ✅ 10 clubs trouvés pour 111
#
# 🔄 Traitement en cours : 112
# ✅ 18 clubs trouvés pour 112
#
# 🔄 Traitement en cours : 113
# ✅ 22 clubs trouvés pour 113
#
# 🔄 Traitement en cours : 114
# ✅ 14 clubs trouvés pour 114
#
# 🔄 Traitement en cours : 115
# ✅ 13 clubs trouvés pour 115
#
# 🔄 Traitement en cours : 116
# ✅ 10 clubs trouvés pour 116
#
# 🔄 Traitement en cours : 117
# ✅ 10 clubs trouvés pour 117
#
# 🔄 Traitement en cours : 118
# ✅ 10 clubs trouvés pour 118
#
# 🔄 Traitement en cours : 119
# ✅ 12 clubs trouvés pour 119
#
# 🔄 Traitement en cours : 120
# ✅ 10 clubs trouvés pour 120
#
# 🔄 Traitement en cours : 121
# ✅ 14 clubs trouvés pour 121
#
# 🔄 Traitement en cours : 122
# ✅ 14 clubs trouvés pour 122
#
# 🔄 Traitement en cours : 123
# ✅ 14 clubs trouvés pour 123
#
# 🔄 Traitement en cours : 124
# ✅ 16 clubs trouvés pour 124
#
# 🔄 Traitement en cours : 125
# ✅ 16 clubs trouvés pour 125
#
# 🔄 Traitement en cours : 126
# ✅ 10 clubs trouvés pour 126
#
# 🔄 Traitement en cours : 127
# ✅ 12 clubs trouvés pour 127
#
# 🔄 Traitement en cours : 128
# ✅ 18 clubs trouvés pour 128
#
# 🔄 Traitement en cours : 129
# ✅ 10 clubs trouvés pour 129
#
# 🔄 Traitement en cours : 130
# ✅ 12 clubs trouvés pour 130
#
# 🔄 Traitement en cours : 131
# ✅ 16 clubs trouvés pour 131
#
# 🔄 Traitement en cours : 132
# ✅ 16 clubs trouvés pour 132
#
# 🔄 Traitement en cours : 133
# ✅ 16 clubs trouvés pour 133
#
# 🔄 Traitement en cours : 134
# ✅ 15 clubs trouvés pour 134
#
# 🔄 Traitement en cours : 135
# ✅ 10 clubs trouvés pour 135
#
# 🔄 Traitement en cours : 136
# ✅ 12 clubs trouvés pour 136
#
# 🔄 Traitement en cours : 137
# ✅ 16 clubs trouvés pour 137
#
# 🔄 Traitement en cours : 138
# ✅ 18 clubs trouvés pour 138
#
# 🔄 Traitement en cours : 139
# ✅ 16 clubs trouvés pour 139
#
# 🔄 Traitement en cours : 140
# ✅ 18 clubs trouvés pour 140
#
# 🔄 Traitement en cours : 141
# ✅ 14 clubs trouvés pour 141
#
# 🔄 Traitement en cours : 142
# ✅ 18 clubs trouvés pour 142
#
# 🔄 Traitement en cours : 143
# ✅ 17 clubs trouvés pour 143
#
# 🔄 Traitement en cours : 144
# ✅ 18 clubs trouvés pour 144
#
# 🔄 Traitement en cours : 145
# ✅ 18 clubs trouvés pour 145
#
# 🔄 Traitement en cours : 146
# ✅ 10 clubs trouvés pour 146
#
# 🔄 Traitement en cours : 147
# ✅ 18 clubs trouvés pour 147
#
# 🔄 Traitement en cours : 148
# ✅ 10 clubs trouvés pour 148
#
# 🔄 Traitement en cours : 149
# ❌ Erreur 502 pour https://www.transfermarkt.fr/usl-league-one/startseite/wettbewerb/USC3
# ⚠️ Aucun club trouvé pour 149
#
# 🔄 Traitement en cours : 150
# ✅ 12 clubs trouvés pour 150
#
# 🔄 Traitement en cours : 151
# ✅ 12 clubs trouvés pour 151
#
# 🔄 Traitement en cours : 152
# ✅ 5 clubs trouvés pour 152
#
# 🔄 Traitement en cours : 153
# ✅ 12 clubs trouvés pour 153
#
# 🔄 Traitement en cours : 154
# ✅ 12 clubs trouvés pour 154
#
# 🔄 Traitement en cours : 155
# ✅ 12 clubs trouvés pour 155
#
# 🔄 Traitement en cours : 156
# ✅ 19 clubs trouvés pour 156
#
# 🔄 Traitement en cours : 157
# ✅ 8 clubs trouvés pour 157
#
# 🔄 Traitement en cours : 158
# ✅ 14 clubs trouvés pour 158
#
# 🔄 Traitement en cours : 159
# ✅ 10 clubs trouvés pour 159
#
# 🔄 Traitement en cours : 160
# ✅ 12 clubs trouvés pour 160
#
# 🔄 Traitement en cours : 161
# ✅ 12 clubs trouvés pour 161
#
# 🔄 Traitement en cours : 162
# ✅ 18 clubs trouvés pour 162
#
# 🔄 Traitement en cours : 163
# ✅ 18 clubs trouvés pour 163
#
# 🔄 Traitement en cours : 164
# ✅ 10 clubs trouvés pour 164
#
# 🔄 Traitement en cours : 165
# ✅ 11 clubs trouvés pour 165
#
# 🔄 Traitement en cours : 166
# ✅ 10 clubs trouvés pour 166
#
# 🔄 Traitement en cours : 167
# ✅ 12 clubs trouvés pour 167
#
# 🔄 Traitement en cours : 168
# ✅ 12 clubs trouvés pour 168
#
# 🔄 Traitement en cours : 169
# ✅ 20 clubs trouvés pour 169
#
# 🔄 Traitement en cours : 170
# ✅ 16 clubs trouvés pour 170
#
# 🔄 Traitement en cours : 171
# ✅ 8 clubs trouvés pour 171
#
# 🔄 Traitement en cours : 172
# ✅ 11 clubs trouvés pour 172
#
# 🔄 Traitement en cours : 173
# ✅ 18 clubs trouvés pour 173
#
# 🔄 Traitement en cours : 174
# ✅ 8 clubs trouvés pour 174
#
# 🔄 Traitement en cours : 175
# ✅ 10 clubs trouvés pour 175
#
# 🔄 Traitement en cours : 176
# ✅ 12 clubs trouvés pour 176
#
# 🔄 Traitement en cours : 177
# ✅ 12 clubs trouvés pour 177
#
# 🔄 Traitement en cours : 178
# ✅ 10 clubs trouvés pour 178
#
# 🔄 Traitement en cours : 179
# ✅ 5 clubs trouvés pour 179
#
# 🔄 Traitement en cours : 180
# ✅ 8 clubs trouvés pour 180
#
# 🔄 Traitement en cours : 181
# ✅ 10 clubs trouvés pour 181
#
# 🔄 Traitement en cours : 182
# ✅ 12 clubs trouvés pour 182
#
# 🔄 Traitement en cours : 183
# ✅ 11 clubs trouvés pour 183
#
# 🔄 Traitement en cours : 184
# ✅ 10 clubs trouvés pour 184
#
# 🔄 Traitement en cours : 185
# ✅ 12 clubs trouvés pour 185
#
# 🔄 Traitement en cours : 186
# ✅ 16 clubs trouvés pour 186
#
# 🔄 Traitement en cours : 187
# ✅ 10 clubs trouvés pour 187
#
# 🔄 Traitement en cours : 188
# ✅ 11 clubs trouvés pour 188
#
# 🔄 Traitement en cours : 189
# ✅ 11 clubs trouvés pour 189
#
# 🔄 Traitement en cours : 190
# ✅ 10 clubs trouvés pour 190
#
# 🔄 Traitement en cours : 191
# ✅ 12 clubs trouvés pour 191
#
# 🔄 Traitement en cours : 192
# ✅ 16 clubs trouvés pour 192
#
# 🔄 Traitement en cours : 193
# ✅ 10 clubs trouvés pour 193
#
# 🔄 Traitement en cours : 194
# ✅ 10 clubs trouvés pour 194
#
# 🔄 Traitement en cours : 195
# ✅ 20 clubs trouvés pour 195
#
# 🔄 Traitement en cours : 196
# ✅ 10 clubs trouvés pour 196
#
# 🔄 Traitement en cours : 197
# ✅ 14 clubs trouvés pour 197
#
# 🔄 Traitement en cours : 198
# ✅ 20 clubs trouvés pour 198
#
# 🔄 Traitement en cours : 199
# ✅ 16 clubs trouvés pour 199
#
# 🔄 Traitement en cours : 200
# ✅ 10 clubs trouvés pour 200
#
# 🔄 Traitement en cours : 201
# ✅ 10 clubs trouvés pour 201
#
# 🔄 Traitement en cours : 202
# ✅ 10 clubs trouvés pour 202
#
# 🔄 Traitement en cours : 203
# ✅ 7 clubs trouvés pour 203
#
# 🔄 Traitement en cours : 204
# ✅ 30 clubs trouvés pour 204
#
# 🔄 Traitement en cours : 205
# ✅ 16 clubs trouvés pour 205
#
#
# 💾 3109 clubs sauvegardés dans d:\FootIQ\assets\equipe\clubs\clubs.csv
#
# 🏁 Fin du programme.
